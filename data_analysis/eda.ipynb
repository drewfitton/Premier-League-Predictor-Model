# %% [markdown]
# # Run feature analysis on match data

# %% [markdown]
# ## Import Packages

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Query statistics table from Postgres for analysis

# %%
db_user = 'db_user'    # Replace with your PostgreSQL username
db_password = 'db_password'  # Replace with your PostgreSQL password
db_host = 'localhost'      # Replace with your PostgreSQL host (e.g., localhost or IP)
db_port = '5432'           # PostgreSQL port (default is 5432)
db_name = 'db_name'    

connection_string = f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"

# Create the SQLAlchemy engine
engine = create_engine(connection_string)

#Create query
query = "SELECT * FROM match_statistics"
# Write the DataFrame to a PostgreSQL table
try:
    # Write the DataFrame to a table named 'your_table_name', replace it with your desired table name
    df = pd.read_sql(query, engine)

    print("Table created successfully.")
    
finally:
    # Ensure connection is closed
    engine.dispose()
    print("Connection closed.")
# Out:
# Table created successfully.
# Connection closed.

# %% [markdown]
# ### See percentage of games that have each result

# %%
#checking class proportions
class_p = (df.winner.value_counts(normalize = True) *100).round(2).reset_index()
class_p.columns = ['winner', '%']
class_p
# Out:
#       winner      %
# 0  HOME_TEAM  45.86
# 1  AWAY_TEAM  29.63
# 2       DRAW  24.51

# %% [markdown]
# ## See correlation between fields and winners

# %%
#creating dummy dependent variables and set of columns to check their correlation with the dependent variables
num_cols = df.dtypes[df.dtypes != 'object'].index.tolist()

cols_to_drop = ['season', 'match_name','date', 'home_team', 'away_team', 'home_score', 'away_score',
                'home_match_points', 'away_match_points']


corr_cols = list(set(num_cols) - set(cols_to_drop))

df['winner_h'] = np.where(df.winner == 'HOME_TEAM', 1, 0)
df['winner_a'] = np.where(df.winner == 'AWAY_TEAM', 1, 0)
df['winner_d'] = np.where(df.winner == 'DRAW', 1, 0)

df[corr_cols + ['winner_h']].corr()['winner_h'].sort_values(ascending = False).reset_index()
# Out:
#                              index  winner_h
# 0                         winner_h  1.000000
# 1                       home_goals  0.639618
# 2                        away_odds  0.358922
# 3     home_away_points_interaction  0.210353
# 4                        away_rank  0.195941
# 5                        draw_odds  0.191792
# 6          home_similar_rank_goals  0.184152
# 7      home_similar_rank_win_ratio  0.165445
# 8                        home_wins  0.163707
# 9                      home_points  0.148429
# 10                  home_goals_for  0.142716
# 11                     away_losses  0.140405
# 12             home_last_3_avg_pts  0.134715
# 13    home_similar_rank_goal_ratio  0.134053
# 14               home_last_3_goals  0.130862
# 15            home_last_3_wavg_pts  0.129846
# 16          home_last_3_wavg_goals  0.128603
# 17                 home_win_streak  0.110110
# 18       away_last_3_goals_against  0.107823
# 19              away_goals_against  0.103724
# 20  away_last_3_wavg_goals_against  0.099595
# 21            home_similar_rank_ga  0.099248
# 22                away_loss_streak  0.076318
# 23                      away_draws  0.048984
# 24                away_draw_streak  0.036169
# 25                      home_draws  0.002608
# 26                home_draw_streak -0.005110
# 27              home_goals_against -0.063212
# 28                  away_goals_for -0.078202
# 29                home_loss_streak -0.082121
# 30                     away_points -0.085630
# 31            away_similar_rank_ga -0.093230
# 32  home_last_3_wavg_goals_against -0.093253
# 33       home_last_3_goals_against -0.097354
# 34    away_similar_rank_goal_ratio -0.099426
# 35                       away_wins -0.104609
# 36                     home_losses -0.110607
# 37          away_last_3_wavg_goals -0.120873
# 38            away_last_3_wavg_pts -0.126735
# 39                 away_win_streak -0.126764
# 40               away_last_3_goals -0.126902
# 41             away_last_3_avg_pts -0.133030
# 42     away_similar_rank_win_ratio -0.152952
# 43         away_similar_rank_goals -0.161095
# 44                       home_rank -0.214595
# 45                       home_odds -0.373895
# 46                      away_goals -0.508011

# %%
df[corr_cols + ['winner_a']].corr()['winner_a'].sort_values(ascending = False).reset_index()
# Out:
#                              index  winner_a
# 0                         winner_a  1.000000
# 1                       away_goals  0.636280
# 2                        home_odds  0.378431
# 3                        home_rank  0.187634
# 4          away_similar_rank_goals  0.167347
# 5      away_similar_rank_win_ratio  0.155771
# 6                        away_wins  0.137152
# 7                  away_win_streak  0.134682
# 8              away_last_3_avg_pts  0.123761
# 9     away_similar_rank_goal_ratio  0.121830
# 10               away_last_3_goals  0.118750
# 11                     home_losses  0.117976
# 12            away_last_3_wavg_pts  0.117527
# 13                     away_points  0.116474
# 14          away_last_3_wavg_goals  0.115682
# 15                  away_goals_for  0.109024
# 16            away_similar_rank_ga  0.086986
# 17       home_last_3_goals_against  0.079124
# 18              home_goals_against  0.075140
# 19  home_last_3_wavg_goals_against  0.071094
# 20                home_loss_streak  0.070438
# 21                      home_draws  0.007823
# 22                home_draw_streak  0.004695
# 23                away_draw_streak -0.021421
# 24                      away_draws -0.041029
# 25            home_similar_rank_ga -0.062856
# 26                away_loss_streak -0.077563
# 27                 home_win_streak -0.089347
# 28              away_goals_against -0.091269
# 29                       draw_odds -0.095604
# 30  away_last_3_wavg_goals_against -0.104871
# 31                  home_goals_for -0.106150
# 32          home_last_3_wavg_goals -0.108228
# 33               home_last_3_goals -0.111706
# 34       away_last_3_goals_against -0.112214
# 35                     home_points -0.116626
# 36            home_last_3_wavg_pts -0.117576
# 37             home_last_3_avg_pts -0.124863
# 38    home_similar_rank_goal_ratio -0.127072
# 39                       home_wins -0.130610
# 40                     away_losses -0.132211
# 41     home_similar_rank_win_ratio -0.141710
# 42         home_similar_rank_goals -0.141899
# 43    home_away_points_interaction -0.184813
# 44                       away_rank -0.210661
# 45                       away_odds -0.328575
# 46                      home_goals -0.478946

# %%
df[corr_cols + ['winner_d']].corr()['winner_d'].sort_values(ascending = False).reset_index()
# Out:
#                              index  winner_d
# 0                         winner_d  1.000000
# 1                        home_rank  0.049404
# 2   home_last_3_wavg_goals_against  0.032554
# 3                        home_odds  0.031402
# 4        home_last_3_goals_against  0.028780
# 5              away_last_3_avg_pts  0.022725
# 6             away_last_3_wavg_pts  0.022049
# 7                away_last_3_goals  0.020944
# 8                 home_loss_streak  0.020356
# 9           away_last_3_wavg_goals  0.017219
# 10                 away_win_streak  0.003875
# 11                     home_losses  0.002892
# 12                home_draw_streak  0.000936
# 13                       away_rank -0.003356
# 14  away_last_3_wavg_goals_against -0.004047
# 15       away_last_3_goals_against -0.005784
# 16                away_loss_streak -0.006071
# 17              home_goals_against -0.006537
# 18                      home_draws -0.011325
# 19                      away_draws -0.013188
# 20                away_draw_streak -0.019157
# 21                     away_losses -0.022298
# 22              away_goals_against -0.023268
# 23             home_last_3_avg_pts -0.023507
# 24                       away_wins -0.024410
# 25                     away_points -0.024445
# 26                  away_goals_for -0.025142
# 27            home_last_3_wavg_pts -0.025602
# 28                 home_win_streak -0.032705
# 29               home_last_3_goals -0.033009
# 30          home_last_3_wavg_goals -0.034084
# 31    home_away_points_interaction -0.042946
# 32                     home_points -0.048135
# 33                       home_wins -0.050989
# 34                  home_goals_for -0.052638
# 35                       away_odds -0.066979
# 36                      away_goals -0.086943
# 37                       draw_odds -0.120678
# 38     away_similar_rank_win_ratio -0.139028
# 39     home_similar_rank_win_ratio -0.179877
# 40                      home_goals -0.232503
